# %%
from filenamehandler import FilenameHandler

fh = FilenameHandler()

# %%
url=r"https://res.cloudinary.com/ekoweb/image/upload/s--4QR-PbEk--/f_auto,h_600,q_auto:eco,w_600/v1/products/9-99687/views/9-99687_crest-10-86mm_cr10.086_01"
url1=r"https://res.cloudinary.com/ekoweb/image/test.jpg"
fh.get_file_extension(url)
# Out:
# '.086_01'

# %%
fh.get_file_extension_from_url_str(url)
# Out:
# '.086_01'

# %%
fh.get_image_extension_from_url_str(url)
# Out:
# ''

# %%
from woosqlitedb import update_image_fields_extension

# %%
csv_dir=r"S:/csv_test/"
update_image_fields_extension(csv_dir=csv_dir)
# Out:
# S:/csv_test/
# Updating image fields extension for:S:\csv_test\p31.csv
#             SKU                               Name    Categories  \
# 0  SK0300163-ES      Insertos Christ para Roundpad   Más vendido
# 1  SK0300164-ES  Montura Bareback de Ante PU Horze  Oferta flash
#
#    Regular price  Sale price  Attribute 1 value(s)  Attribute 1 name  \
# 0          45.00        13.5                   NaN               NaN
# 1          99.99        30.0                   NaN               NaN
#
#               Images                                          ImagesUrl  \
# 0   17691_NTL_1.webp  https://www.horze.es/dw/image/v2/AATB_PRD/on/d...
# 1  17695_099_01.webp  https://www.horze.es/dw/image/v2/AATB_PRD/on/d...
#
#        Tags                                            PageUrl  \
# 0  position  https://www.horze.es/accesorios-de-monturas/in...
# 1  position  https://www.horze.es/monturas-a-pelo-bareback/...
#
#                                          Description
# ...
