# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Administrator\Desktop\woo_df\cf_domains.template.readonly.csv")

# %%
df
# Out:
# Empty DataFrame
# Columns: [domain, ip, forward, security, ssl, Note]
# Index: []

# %%
len(df)
# Out:
# 0

# %%
df.shape
# Out:
# (0, 6)
