# %%
from imgdown import download_by_curl
from comutils import get_image_filebasename

# %%
# download_by_curl(
#     url="https://esd.equipment/media/catalog/product/c/q/cq2_12-100-dmz_301.jpg",
#     output_path="./cq2_12-100-dmz_301.jpg",
#     referer="https://esd.equipment/"
# )

# %%
get_image_filebasename(['png', 'jpg'])('abc.png.jpg')
# Out:
# 'abc.png'

# %%
get_image_filebasename(['png', 'jpg'])('abc.png.JPG')
# Out:
# 'abc.png'
