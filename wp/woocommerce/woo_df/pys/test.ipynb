# %%
from comutils import complete_image_file_extension,get_image_filebasename

# %%
complete_image_file_extension("abc.jpg")
# Out:
# 'abc.jpg'

# %%
complete_image_file_extension("abc.jpg",default_extension=".webp")
# Out:
# 'abc.jpg'

# %%
complete_image_file_extension("abc.jpg.png",default_extension=".webp")
# Out:
# 'abc.jpg.png'

# %%
complete_image_file_extension("abcjpg",default_extension=".webp")
# Out:
# 'abcjpg.webp'
