# %%
import pandas as pd
import os

# %%
from filenamehandler import FilenameHandler
fh=FilenameHandler()

# %%
fh.get_file_extension_from_file_by_magic(r"C:/Users/Administrator/Desktop/xero-shoes_mew-dgs_3.jpg")
# Out:
# '.webp'
