# %%
import os 
import pandas as pd

# %%
filename=r"C:/dk/spider_tasks/domains.xlsx"
domain_list = []
if format == "excel" or filename.endswith(".xlsx"):
    df = pd.read_excel(filename)
    dl = df.iloc[:, 0].dropna().to_list()
    domain_list.extend(dl)

# %%
from comutils import get_main_domain_name_from_str
for item in domain_list :
    domain_name = get_main_domain_name_from_str(item)
    print(domain_name)
# Out:
# custombowequipment.com
# togllc.com
# seek-one.com
# southlandarchery.com
# elusivewildlife.com
# ameyxgs.com
# elkshape.com
# lumenok.com
# vanguardcrossbows.com
# tenpointcrossbows.com
# centerpointarchery.com
# blackeaglearrows.com
# huntingdoor.com
# ravincrossbows.com
# toothofthearrowbroadheads.com
# wyverncreations.com
# killerinstinctcrossbows.com
# excaliburcrossbow.com
# excaliburcrossbow.com
# jamesriverarchery.com
# kustomkingarchery.com
# nikabow.com
# southwestarcheryusa.com
# skatersadvocate.com
# easternboarder.com
# fishnstuff.com
# littlemountainoutfitters.com
# arrowsunlimited.com
# trek-expert.com
# eastforkbikes.com
