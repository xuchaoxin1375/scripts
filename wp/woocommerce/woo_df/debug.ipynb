# %%
import pandas as pd
from woosqlitedb import update_image_fields_from_legacy
f=r"S:/p1.csv"
update_image_fields_from_legacy(f)
# Out:
# not valid filename(empty or no extension), use url hash as filename!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       2 from woosqlitedb import update_image_fields_from_legacy
#       3 f=r"S:/p1.csv"
# ----> 4 update_image_fields_from_legacy(f)
#
# File C:\repos\scripts\wp\woocommerce\woo_df\woosqlitedb.py:50, in update_image_fields_from_legacy(csv_file)
#      48     return  # 相关字段已经存在,不需要更新
#      49 df[IMAGE_URL] = df[IMAGES]
# ---> 50 df[IMAGES] = df[IMAGES].apply(fh.get_filename_from_url)
#      51 df.to_csv(csv_file, index=False)
#
# File c:\ProgramData\scoop\apps\miniconda3\24.9.2-0\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
# ...

# %%
df=pd.read_csv(f)

# %%
df

# %%
from wooenums import CSVProductFields, DBProductFields, ImageMode, LanguagesHotSale
IMAGES = CSVProductFields.IMAGES.value
IMAGE_URL = CSVProductFields.IMAGES_URL.value

# %%
df[IMAGE_URL] = df[IMAGES]

# %%
df[IMAGE_URL]

# %%
df[IMAGES]
