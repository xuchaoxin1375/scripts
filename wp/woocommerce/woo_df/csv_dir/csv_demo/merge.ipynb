# %%
import comutils

# %%
comutils.remove_duplicate_rows('./renew.csv',subset=['H1'],inplace=True)
# Out:
# remove duplicate rows in subset [['H1']] from ./renew.csv
#     H1   H2
# 0  L11  L12
# 1  L21  L22
# 2  G11  G12
# 3  G21  G22
