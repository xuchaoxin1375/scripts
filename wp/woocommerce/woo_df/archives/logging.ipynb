# %%
import logging

logging.basicConfig(
    filename='log.log',          # 日志文件名
    filemode='w',               # 写入模式：'a'追加，'w'覆盖
    level=logging.INFO,         # 记录级别
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

logging.info('这是一条信息日志')
logging.info('这是一条信息日志x2')

# %%
[
    {'id': 1, 'name': 'Alice', 'score': 90, 'passed': True},
    {'id': 2, 'name': 'Bob', 'score': 95, 'passed': True},
    {'id': 3, 'name': 'Charlie', 'score': 83, 'passed': True}
]
# Out:
# [{'id': 1, 'name': 'Alice', 'score': 90, 'passed': True},
#  {'id': 2, 'name': 'Bob', 'score': 95, 'passed': True},
#  {'id': 3, 'name': 'Charlie', 'score': 83, 'passed': True}]

# %%
rows_lst = [
    {'id': 1, 'name': 'Alice', 'score': 85},
    {'id': 2, 'name': 'Bob', 'score': 90},
    {'id': 3, 'name': 'Charlie', 'score': 78}
]

# 遍历并修改字典内容
for idx, row in enumerate(rows_lst):
    row['score'] += 5  # 给每个人加5分
    row['passed'] = row['score'] >= 80  # 添加新字段
    
    # 也可以通过索引直接访问修改
    # rows_lst[idx]['score'] += 5  # 效果相同

print(rows_lst)
# Out:
# [{'id': 1, 'name': 'Alice', 'score': 90, 'passed': True}, {'id': 2, 'name': 'Bob', 'score': 95, 'passed': True}, {'id': 3, 'name': 'Charlie', 'score': 83, 'passed': True}]
