# %%
import pandas as pd
df=pd.read_csv("./csv_dir/img.csv")

# %%
df
# Out:
#    id       image
# 0   1     abc.jpg
# 1   2  de.gif.png
# 2   3    ghi.webp
# 3   4         jkl
# 4   5        mno.

# %%
# ...existing code...
df['image'].str.rsplit('.', n=1).str[0] + '.webp'
# ...existing code...
# Out:
# 0       abc.webp
# 1    de.gif.webp
# 2       ghi.webp
# 3       jkl.webp
# 4       mno.webp
# Name: image, dtype: object

# %%
"abc.jpg".rsplit('.', 1)
# Out:
# ['abc', 'jpg']

# %%
"abc".rsplit('.', 1)
# Out:
# ['abc']
