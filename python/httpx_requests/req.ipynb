# %%
import httpx
url="https://www.baidu.com"
# Basic Auth
resp = httpx.get(url, auth=("username", "password"))

# %%
resp.url
# Out:
# URL('https://www.baidu.com')

# %%
resp
# Out:
# <Response [200 OK]>
