# %%
"café".encode("utf-8")

# %%
"你".encode()

# %%
bytes([0xe4,0xbd,0xa0]).decode()

# %%
bytes([72, 101, 108, 108, 111])

# %%
b"hello".decode()

# %%
"hello".encode()

# %%
bytes("你好hello",'utf-8').find(b"ll")

# %%
"你好hello".encode()

# %%
data = "你好hello".encode()

print(data[0])      # 228
print(data[0:1])    # b'\xe4'

# %%
r'\\'.encode()

# %%
print("\\")

# %%
bad_bytes = b'\xff\xfe'
bad_bytes.decode("utf-8", errors="replace")  # '��'
# bad_bytes.decode("utf-8", errors="ignore")   # ''

# %%
s = "你好abc"

for x in s.encode():
    print(x)
